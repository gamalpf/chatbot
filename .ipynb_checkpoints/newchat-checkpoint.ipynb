# %%
import nltk
import json
import random
import numpy as np
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Dropout
from tensorflow.keras.optimizers import SGD
from tensorflow.keras.models import load_model

import nltk
from nltk.stem import PorterStemmer

# Descargar los datos necesarios de NLTK
nltk.download('punkt')

# Crear el objeto stemmer
stemmer = PorterStemmer()

# Leer el archivo intents.json
with open('intents.json') as file:
    data = json.load(file)

# Inicializar las listas necesarias
words = []
labels = []
docs_x = []
docs_y = []


# Recorrer los patrones en el archivo JSON
for intent in data['intents']:
    for pattern in intent['patterns']:
        # Tokenizar las palabras
        wrds = nltk.word_tokenize(pattern)
        words.extend(wrds)
        # Agregar los patrones y las etiquetas correspondientes
        docs_x.append(wrds)
        docs_y.append(intent['tag'])

    # Agregar las etiquetas a la lista
    if intent['tag'] not in labels:
        labels.append(intent['tag'])

# Eliminar duplicados y ordenar la lista de palabras
words = sorted(list(set([stemmer.stem(w.lower()) for w in words])))

# Ordenar la lista de etiquetas
labels = sorted(labels)

# Crear una matriz de entrada para el modelo
training = []
output = []
out_empty = [0] * len(labels)

for idx, doc in enumerate(docs_x):
    # Crear una bolsa de palabras para cada patrón
    bag = []
    wrds = [stemmer.stem(w.lower()) for w in doc]

    for w in words:
        if w in wrds:
            bag.append(1)
        else:
            bag.append(0)

    # Crear una matriz de salida con la etiqueta correspondiente
    output_row = out_empty[:]
    output_row[labels.index(docs_y[idx])] = 1

    training.append(bag)
    output.append(output_row)

# Convertir las listas en arrays de Numpy
training = np.array(training)
output = np.array(output)


# Definir el modelo de la red neuronal
model = Sequential()
model.add(Dense(128, input_shape=(len(training[0]),), activation='relu'))
model.add(Dropout(0.5))
model.add(Dense(64, activation='relu'))
model.add(Dropout(0.5))
model.add(Dense(32, activation='relu'))
model.add(Dropout(0.5))
model.add(Dense(len(output[0]), activation='softmax'))
# Compilar y entrenar el modelo
model.compile(loss='categorical_crossentropy', optimizer=SGD(lr=0.01, momentum=0.9, nesterov=True), metrics=['accuracy'])
model.fit(training, output, epochs=200, batch_size=5, verbose=1)

# Guardar el modelo
model.save('chatbot_model.h5')

# Cargar el modelo
model = load_model('chatbot_model.h5')

# Función para procesar las entradas de usuario y generar respuestas
def process_input(user_input):
    # Tokenizar y stemmizar la entrada del usuario
    user_words = nltk.word_tokenize(user_input)
    user_words = [stemmer.stem(word.lower()) for word in user_words]

    # Crear una bolsa de palabras para la entrada del usuario
    user_bag = [0] * len(words)
    for word in user_words:
        for i, w in enumerate(words):
            if w == word:
                user_bag[i] = 1

    # Hacer una predicción con el modelo
    prediction = model.predict(np.array([user_bag]))[0]
    predicted_label = labels[np.argmax(prediction)]

    # Seleccionar una respuesta aleatoria de las respuestas correspondientes a la etiqueta predicha
    response = random.choice([intent['responses'] for intent in data['intents'] if intent['tag'] == predicted_label][0])

    return response

# Función para interactuar con el usuario
def chat():
    print("¡Bienvenido al chatbot! Escribe 'salir' para terminar.")
    while True:
        user_input = input("Tú: ")
        if user_input.lower() == "salir":
            break

        response = process_input(user_input)
        print("Chatbot:", response)

# Iniciar el chatbot
chat()
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\lenovo\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# WARNING:absl:`lr` is deprecated in Keras optimizer, please use `learning_rate` or use the legacy optimizer, e.g.,tf.keras.optimizers.legacy.SGD.
# Epoch 1/200
# 7/7 [==============================] - 2s 7ms/step - loss: 2.2723 - accuracy: 0.2000
# Epoch 2/200
# 7/7 [==============================] - 0s 5ms/step - loss: 2.2252 - accuracy: 0.1714
# Epoch 3/200
# 7/7 [==============================] - 0s 5ms/step - loss: 2.1626 - accuracy: 0.2000
# Epoch 4/200
# 7/7 [==============================] - 0s 7ms/step - loss: 2.1655 - accuracy: 0.1429
# Epoch 5/200
# 7/7 [==============================] - 0s 5ms/step - loss: 2.
200
# 7/7 [==============================] - 0s 4ms/step - loss: 0.4513 - accuracy: 0.8571
# Epoch 67/200
# 7/7 [==============================] - 0s 4ms/step - loss: 0.5758 - accuracy: 0.8286
# Epoch 68/200
# 7/7 [==============================] - 0s 4ms/step - loss: 0.7591 - accuracy: 0.8000
# Epoch 69/200
# 7/7 [==============================] - 0s 7ms/step - loss: 0.5523 - accuracy: 0.7143
# Epoch 70/200
# 7/7 [==============================] - 0s 3ms/step - loss: 0.5124 - accuracy: 0.8000
# Epoch 71/200
# 7/7 [==============================] - 0s 5ms/step - loss: 0.5817 - accuracy: 0.7714
# Epoch 72/200
# 7/7 [==============================] - 0s 3ms/step - loss: 0.4704 - accuracy: 0.8286
# Epoch 73/200
# 7/7 [==============================] - 0s 4ms/step - loss: 0.3669 - accuracy: 0.9143
# Epoch 74/200
# 7/7 [==============================] - 0s 5ms/step - loss: 0.6984 - accuracy: 0.7143
# Epoch 75/200
# 7/7 [==============================] - 0s 4ms/step - loss: 0.6100 - accuracy: 0.8000
# Epoch 76/200
# 7/7 [==============================] - 0s 3ms/step - loss: 0.3385 - accuracy: 0.8571
# Epoch 77/200
# 7/7 [==============================] - 0s 5ms/step - loss: 0.9557 - accuracy: 0.7714
# Epoch 78/200
# 7/7 [==============================] - 0s 6ms/step - loss: 0.8392 - accuracy: 0.7143
# Epoch 79/200
# 7/7 [==============================] - 0s 5ms/step - loss: 0.6794 - accuracy: 0.7429
# Epoch 80/200
# 7/7 [==============================] - 0s 3ms/step - loss: 0.7241 - accuracy: 0.7429
# Epoch 81/200
# 7/7 [==============================] - 0s 4ms/step - loss: 0.3327 - accuracy: 0.8857
# Epoch 82/200
# 7/7 [==============================] - 0s 8ms/step - loss: 0.3423 - accuracy: 0.8571
# Epoch 83/200
# 7/7 [==============================] - 0s 5ms/step - loss: 0.7665 - accuracy: 0.7429
# Epoch 84/200
# 7/7 [==============================] - 0s 4ms/step - loss: 0.6688 - accuracy: 0.8000
# Epoch 85/200
# 7/7 [==============================] - 0s 4ms/step - loss: 0.4285 - accuracy: 0.8000
# Epoch 86/200
# 7/7 [==============================] - 0s 4ms/step - loss: 0.6601 - accuracy: 0.7714
# Epoch 87/200
# 7/7 [==============================] - 0s 3ms/step - loss: 0.5158 - accuracy: 0.7714
# Epoch 88/200
# 7/7 [==============================] - 0s 3ms/step - loss: 0.4212 - accuracy: 0.8286
# Epoch 89/200
# 7/7 [==============================] - 0s 3ms/step - loss: 0.5600 - accuracy: 0.9143
# Epoch 90/200
# 7/7 [==============================] - 0s 4ms/step - loss: 0.3619 - accuracy: 0.8857
# Epoch 91/200
# 7/7 [==============================] - 0s 4ms/step - loss: 0.4743 - accuracy: 0.9143
# Epoch 92/200
# 7/7 [==============================] - 0s 4ms/step - loss: 0.4144 - accuracy: 0.8571
# Epoch 93/200
# 7/7 [==============================] - 0s 5ms/step - loss: 0.6457 - accuracy: 0.7143
# Epoch 94/200
# 7/7 [==============================] - 0s 4ms/step - loss: 0.4457 - accuracy: 0.8000
# Epoch 95/200
# 7/7 [==============================] - 0s 3ms/step - loss: 0.4084 - accuracy: 0.8000
# Epoch 96/200
# 7/7 [==============================] - 0s 3ms/step - loss: 0.2526 - accuracy: 0.9143
# Epoch 97/200
# 7/7 [==============================] - 0s 5ms/step - loss: 0.2911 - accuracy: 0.9143
# Epoch 98/200
# 7/7 [==============================] - 0s 3ms/step - loss: 0.4783 - accuracy: 0.8571
# Epoch 99/200
# 7/7 [==============================] - 0s 4ms/step - loss: 0.4710 - accuracy: 0.8000
# Epoch 100/200
# 7/7 [==============================] - 0s 4ms/step - loss: 0.3174 - accuracy: 0.9143
# Epoch 101/200
# 7/7 [==============================] - 0s 4ms/step - loss: 0.4443 - accuracy: 0.8571
# Epoch 102/200
# 7/7 [==============================] - 0s 4ms/step - loss: 0.4633 - accuracy: 0.8286
# Epoch 103/200
# 7/7 [==============================] - 0s 5ms/step - loss: 0.2558 - accuracy: 0.9143
# Epoch 104/200
# 7/7 [==============================] - 0s 3ms/step - loss: 0.3912 - accuracy: 0.8857
# Epoch 105/200
# 7/7 [==============================] - 0s 4ms/step - loss: 0.3669 - accuracy: 0.8571
# Epoch 106/200
# 7/7 [==============================] - 0s 3ms/step - loss: 0.4643 - accuracy: 0.8857
# Epoch 107/200
# 7/7 [==============================] - 0s 3ms/step - loss: 0.3795 - accuracy: 0.8286
# Epoch 108/200
# 7/7 [==============================] - 0s 4ms/step - loss: 0.2526 - accuracy: 0.9143
# Epoch 109/200
# 7/7 [==============================] - 0s 4ms/step - loss: 0.3588 - accuracy: 0.8571
# Epoch 110/200
# 7/7 [==============================] - 0s 5ms/step - loss: 0.3492 - accuracy: 0.8857
# Epoch 111/200
# 7/7 [==============================] - 0s 5ms/step - loss: 0.2544 - accuracy: 0.9143
# Epoch 112/200
# 7/7 [==============================] - 0s 4ms/step - loss: 0.4221 - accuracy: 0.9143
# Epoch 113/200
# 7/7 [==============================] - 0s 4ms/step - loss: 0.2984 - accuracy: 0.8857
# Epoch 114/200
# 7/7 [==============================] - 0s 4ms/step - loss: 0.5310 - accuracy: 0.8000
# Epoch 115/200
# 7/7 [==============================] - 0s 4ms/step - loss: 0.3663 - accuracy: 0.8857
# Epoch 116/200
# 7/7 [==============================] - 0s 4ms/step - loss: 0.4436 - accuracy: 0.8286
# Epoch 117/200
# 7/7 [==============================] - 0s 7ms/step - loss: 0.6030 - accuracy: 0.8000
# Epoch 118/200
# 7/7 [==============================] - 0s 4ms/step - loss: 0.2940 - accuracy: 0.8571
# Epoch 119/200
# 7/7 [==============================] - 0s 4ms/step - loss: 0.1912 - accuracy: 0.9429
# Epoch 120/200
# 7/7 [==============================] - 0s 4ms/step - loss: 0.4814 - accuracy: 0.8857
# Epoch 121/200
# 7/7 [==============================] - 0s 4ms/step - loss: 0.1872 - accuracy: 0.9143
# Epoch 122/200
# 7/7 [==============================] - 0s 5ms/step - loss: 0.5081 - accuracy: 0.8571
# Epoch 123/200
# 7/7 [==============================] - 0s 4ms/step - loss: 0.2481 - accuracy: 0.9143
# Epoch 124/200
# 7/7 [==============================] - 0s 5ms/step - loss: 0.2398 - accuracy: 0.9143
# Epoch 125/200
# 7/7 [==============================] - 0s 4ms/step - loss: 0.3306 - accuracy: 0.9429
# Epoch 126/200
# 7/7 [==============================] - 0s 4ms/step - loss: 0.4100 - accuracy: 0.8571
# Epoch 127/200
# 7/7 [==============================] - 0s 4ms/step - loss: 0.2771 - accuracy: 0.9143
# Epoch 128/200
# 7/7 [==============================] - 0s 4ms/step - loss: 0.4248 - accuracy: 0.8857
# Epoch 129/200
# 7/7 [==============================] - 0s 4ms/step - loss: 0.2932 - accuracy: 0.8857
# Epoch 130/200
# 7/7 [==============================] - 0s 4ms/step - loss: 0.2054 - accuracy: 0.9143
# Epoch 131/200
# 7/7 [==============================] - 0s 5ms/step - loss: 0.2606 - accuracy: 0.9143
# Epoch 132/200
# 7/7 [==============================] - 0s 5ms/step - loss: 0.3935 - accuracy: 0.8571
# Epoch 133/200
# 7/7 [==============================] - 0s 6ms/step - loss: 0.3989 - accuracy: 0.8571
# Epoch 134/200
# 7/7 [==============================] - 0s 4ms/step - loss: 0.1861 - accuracy: 0.9143
# Epoch 135/200
# 7/7 [==============================] - 0s 5ms/step - loss: 0.2678 - accuracy: 0.9143
# Epoch 136/200
# 7/7 [==============================] - 0s 4ms/step - loss: 0.2710 - accuracy: 0.8857
# Epoch 137/200
# 7/7 [==============================] - 0s 4ms/step - loss: 0.2034 - accuracy: 0.9143
# Epoch 138/200
# 7/7 [==============================] - 0s 4ms/step - loss: 0.2470 - accuracy: 0.9714
# Epoch 139/200
# 7/7 [==============================] - 0s 4ms/step - loss: 0.2416 - accuracy: 0.9143
# Epoch 140/200
# 7/7 [==============================] - 0s 6ms/step - loss: 0.1805 - accuracy: 0.9429
# Epoch 141/200
# 7/7 [==============================] - 0s 4ms/step - loss: 0.4765 - accuracy: 0.8857
# Epoch 142/200
# 7/7 [==============================] - 0s 4ms/step - loss: 0.2003 - accuracy: 0.9714
# Epoch 143/200
# 7/7 [==============================] - 0s 4ms/step - loss: 0.4768 - accuracy: 0.8000
# Epoch 144/200
# 7/7 [==============================] - 0s 5ms/step - loss: 0.3481 - accuracy: 0.9143
# Epoch 145/200
# 7/7 [==============================] - 0s 5ms/step - loss: 0.2046 - accuracy: 0.9714
# Epoch 146/200
# 7/7 [==============================] - 0s 3ms/step - loss: 0.1873 - accuracy: 0.8857
# Epoch 147/200
# 7/7 [==============================] - 0s 5ms/step - loss: 0.2279 - accuracy: 0.9143
# Epoch 148/200
# 7/7 [==============================] - 0s 4ms/step - loss: 0.2971 - accuracy: 0.8857
# Epoch 149/200
# 7/7 [==============================] - 0s 4ms/step - loss: 0.4132 - accuracy: 0.8286
# Epoch 150/200
# 7/7 [==============================] - 0s 4ms/step - loss: 0.2513 - accuracy: 0.8857
# Epoch 151/200
# 7/7 [==============================] - 0s 5ms/step - loss: 0.4201 - accuracy: 0.8286
# Epoch 152/200
# 7/7 [==============================] - 0s 4ms/step - loss: 0.3015 - accuracy: 0.9143
# Epoch 153/200
# 7/7 [==============================] - 0s 4ms/step - loss: 0.2857 - accuracy: 0.9429
# Epoch 154/200
# 7/7 [==============================] - 0s 5ms/step - loss: 0.3148 - accuracy: 0.8857
# Epoch 155/200
# 7/7 [==============================] - 0s 4ms/step - loss: 0.1365 - accuracy: 0.9429
# Epoch 156/200
# 7/7 [==============================] - 0s 5ms/step - loss: 0.3564 - accuracy: 0.8857
# Epoch 157/200
# 7/7 [==============================] - 0s 5ms/step - loss: 0.1831 - accuracy: 0.9143
# Epoch 158/200
# 7/7 [==============================] - 0s 2ms/step - loss: 0.2343 - accuracy: 0.8857
# Epoch 159/200
# 7/7 [==============================] - 0s 5ms/step - loss: 0.1359 - accuracy: 1.0000
# Epoch 160/200
# 7/7 [==============================] - 0s 5ms/step - loss: 0.2455 - accuracy: 0.9143
# Epoch 161/200
# 7/7 [==============================] - 0s 5ms/step - loss: 0.3079 - accuracy: 0.9143
# Epoch 162/200
# 7/7 [==============================] - 0s 5ms/step - loss: 0.2830 - accuracy: 0.9429
# Epoch 163/200
# 7/7 [==============================] - 0s 4ms/step - loss: 0.1582 - accuracy: 0.9714
# Epoch 164/200
# 7/7 [==============================] - 0s 5ms/step - loss: 0.2971 - accuracy: 0.9143
# Epoch 165/200
# 7/7 [==============================] - 0s 5ms/step - loss: 0.1108 - accuracy: 0.9714
# Epoch 166/200
# 7/7 [==============================] - 0s 5ms/step - loss: 0.2487 - accuracy: 0.9143
# Epoch 167/200
# 7/7 [==============================] - 0s 3ms/step - loss: 0.1742 - accuracy: 0.9143
# Epoch 168/200
# 7/7 [==============================] - 0s 4ms/step - loss: 0.3524 - accuracy: 0.9714
# Epoch 169/200
# 7/7 [==============================] - 0s 4ms/step - loss: 0.3862 - accuracy: 0.8857
# Epoch 170/200
# 7/7 [==============================] - 0s 6ms/step - loss: 0.1576 - accuracy: 0.9429
# Epoch 171/200
# 7/7 [==============================] - 0s 3ms/step - loss: 0.4633 - accuracy: 0.8857
# Epoch 172/200
# 7/7 [==============================] - 0s 5ms/step - loss: 0.3052 - accuracy: 0.8857
# Epoch 173/200
# 7/7 [==============================] - 0s 4ms/step - loss: 0.2043 - accuracy: 0.9429
# Epoch 174/200
# 7/7 [==============================] - 0s 4ms/step - loss: 0.1487 - accuracy: 0.9429
# Epoch 175/200
# 7/7 [==============================] - 0s 4ms/step - loss: 0.1298 - accuracy: 0.9714
# Epoch 176/200
# 7/7 [==============================] - 0s 5ms/step - loss: 0.1448 - accuracy: 0.9429
# Epoch 177/200
# 7/7 [==============================] - 0s 5ms/step - loss: 0.1433 - accuracy: 0.9429
# Epoch 178/200
# 7/7 [==============================] - 0s 5ms/step - loss: 0.2173 - accuracy: 0.9143
# Epoch 179/200
# 7/7 [==============================] - 0s 5ms/step - loss: 0.3536 - accuracy: 0.9143
# Epoch 180/200
# 7/7 [==============================] - 0s 4ms/step - loss: 0.1651 - accuracy: 0.9143
# Epoch 181/200
# 7/7 [==============================] - 0s 4ms/step - loss: 0.1171 - accuracy: 0.9714
# Epoch 182/200
# 7/7 [==============================] - 0s 7ms/step - loss: 0.0866 - accuracy: 1.0000
# Epoch 183/200
# 7/7 [==============================] - 0s 4ms/step - loss: 0.5817 - accuracy: 0.8857
# Epoch 184/200
# 7/7 [==============================] - 0s 4ms/step - loss: 0.2743 - accuracy: 0.8857
# Epoch 185/200
# 7/7 [==============================] - 0s 5ms/step - loss: 0.2522 - accuracy: 0.9429
# Epoch 186/200
# 7/7 [==============================] - 0s 5ms/step - loss: 0.5483 - accuracy: 0.8571
# Epoch 187/200
# 7/7 [==============================] - 0s 4ms/step - loss: 0.4743 - accuracy: 0.8571
# Epoch 188/200
# 7/7 [==============================] - 0s 5ms/step - loss: 0.1323 - accuracy: 0.9429
# Epoch 189/200
# 7/7 [==============================] - 0s 5ms/step - loss: 0.2031 - accuracy: 0.9714
# Epoch 190/200
# 7/7 [==============================] - 0s 4ms/step - loss: 0.3652 - accuracy: 0.8286
# Epoch 191/200
# 7/7 [==============================] - 0s 5ms/step - loss: 0.2854 - accuracy: 0.8857
# Epoch 192/200
# 7/7 [==============================] - 0s 5ms/step - loss: 0.4412 - accuracy: 0.8000
# Epoch 193/200
# 7/7 [==============================] - 0s 5ms/step - loss: 0.2241 - accuracy: 0.9429
# Epoch 194/200
# 7/7 [==============================] - 0s 7ms/step - loss: 0.1831 - accuracy: 0.9429
# Epoch 195/200
# 7/7 [==============================] - 0s 5ms/step - loss: 0.1964 - accuracy: 0.9143
# Epoch 196/200
# 7/7 [==============================] - 0s 5ms/step - loss: 0.1796 - accuracy: 0.9429
# Epoch 197/200
# 7/7 [==============================] - 0s 5ms/step - loss: 0.0795 - accuracy: 0.9714
# Epoch 198/200
# 7/7 [==============================] - 0s 4ms/step - loss: 0.6204 - accuracy: 0.8571
# Epoch 199/200
# 7/7 [==============================] - 0s 5ms/step - loss: 0.1274 - accuracy: 0.9714
# Epoch 200/200
# 7/7 [==============================] - 0s 5ms/step - loss: 0.3111 - accuracy: 0.8857
# ¡Bienvenido al chatbot! Escribe 'salir' para terminar.
