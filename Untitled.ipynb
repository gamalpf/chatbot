# %%
pip install python-telegram-bot

# %%
pip install python-telegram-bot[all]

# %%
import json
import random
import numpy as np
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Dropout
from tensorflow.keras.optimizers import SGD
from tensorflow.keras.models import load_model
import nltk
from nltk.stem import PorterStemmer
from telegram.ext import Updater, CommandHandler, MessageHandler, Filters

# Descargar los datos necesarios de NLTK
nltk.download('punkt')

# Crear el objeto stemmer
stemmer = PorterStemmer()

# Leer el archivo intents.json
with open('intents.json') as file:
    data = json.load(file)

# Inicializar las listas necesarias
words = []
labels = []
docs_x = []
docs_y = []

# Recorrer los patrones en el archivo JSON
for intent in data['intents']:
    for pattern in intent['patterns']:
        # Tokenizar las palabras
        wrds = nltk.word_tokenize(pattern)
        words.extend(wrds)
        # Agregar los patrones y las etiquetas correspondientes
        docs_x.append(wrds)
        docs_y.append(intent['tag'])

    # Agregar las etiquetas a la lista
    if intent['tag'] not in labels:
        labels.append(intent['tag'])

# Eliminar duplicados y ordenar la lista de palabras
words = sorted(list(set([stemmer.stem(w.lower()) for w in words])))

# Ordenar la lista de etiquetas
labels = sorted(labels)

# Crear una matriz de entrada para el modelo
training = []
output = []
out_empty = [0] * len(labels)

for idx, doc in enumerate(docs_x):
    # Crear una bolsa de palabras para cada patrón
    bag = []
    wrds = [stemmer.stem(w.lower()) for w in doc]

    for w in words:
        if w in wrds:
            bag.append(1)
        else:
            bag.append(0)

    # Crear una matriz de salida con la etiqueta correspondiente
    output_row = out_empty[:]
    output_row[labels.index(docs_y[idx])] = 1

    training.append(bag)
    output.append(output_row)

# Convertir las listas en arrays de Numpy
training = np.array(training)
output = np.array(output)

# Definir el modelo de la red neuronal
model = Sequential()
model.add(Dense(128, input_shape=(len(training[0]),), activation='relu'))
model.add(Dropout(0.5))
model.add(Dense(64, activation='relu'))
model.add(Dropout(0.5))
model.add(Dense(32, activation='relu'))
model.add(Dropout(0.5))
model.add(Dense(len(output[0]), activation='softmax'))

# Compilar y entrenar el modelo
model.compile(loss='categorical_crossentropy', optimizer=SGD(lr=0.01, momentum=0.9, nesterov=True), metrics=['accuracy'])
model.fit(training, output, epochs=200, batch_size=5, verbose=1)

# Guardar el modelo
model.save('chatbot_model.h5')

# Cargar el modelo
model = load_model('chatbot_model.h5')


import json
import random
import numpy as np
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Dropout
from tensorflow.keras.optimizers import SGD
from tensorflow.keras.models import load_model
import nltk
from nltk.stem import PorterStemmer


# Descargar los datos necesarios de NLTK
nltk.download('punkt')

# Crear el objeto stemmer
stemmer = PorterStemmer()

# Leer el archivo intents.json
with open('intents.json') as file:
    data = json.load(file)

# Inicializar las listas necesarias
words = []
labels = []
docs_x = []
docs_y = []

# Recorrer los patrones en el archivo JSON
for intent in data['intents']:
    for pattern in intent['patterns']:
        # Tokenizar las palabras
        wrds = nltk.word_tokenize(pattern)
        words.extend(wrds)
        # Agregar los patrones y las etiquetas correspondientes
        docs_x.append(wrds)
        docs_y.append(intent['tag'])

    # Agregar las etiquetas a la lista
    if intent['tag'] not in labels:
        labels.append(intent['tag'])

# Eliminar duplicados y ordenar la lista de palabras
words = sorted(list(set([stemmer.stem(w.lower()) for w in words])))

# Ordenar la lista de etiquetas
labels = sorted(labels)

# Crear una matriz de entrada para el modelo
training = []
output = []
out_empty = [0] * len(labels)

for idx, doc in enumerate(docs_x):
    # Crear una bolsa de palabras para cada patrón
    bag = []
    wrds = [stemmer.stem(w.lower()) for w in doc]

    for w in words:
        if w in wrds:
            bag.append(1)
        else:
            bag.append(0)

    # Crear una matriz de salida con la etiqueta correspondiente
    output_row = out_empty[:]
    output_row[labels.index(docs_y[idx])] = 1

    training.append(bag)
    output.append(output_row)

# Convertir las listas en arrays de Numpy
training = np.array(training)
output = np.array(output)

# Definir el modelo de la red neuronal
model = Sequential()
model.add(Dense(128, input_shape=(len(training[0]),), activation='relu'))
model.add(Dropout(0.5))
model.add(Dense(64, activation='relu'))
model.add(Dropout(0.5))
model.add(Dense(32, activation='relu'))
model.add(Dropout(0.5))
model.add(Dense(len(output[0]), activation='softmax'))

# Compilar y entrenar el modelo
model.compile(loss='categorical_crossentropy', optimizer=SGD(lr=0.01, momentum=0.9, nesterov=True), metrics=['accuracy'])
model.fit(training, output, epochs=200, batch_size=5, verbose=1)

# Guardar el modelo
model.save('chatbot_model.h5')

# Cargar el modelo
model = load_model('chatbot_model.h5')

#Función para procesar las entradas de usuario y generar respuestas
def process_input(user_input):
    # Tokenizar y stemmizar la entrada del usuario
    user_words = nltk.word_tokenize(user_input)
    user_words = [stemmer.stem(word.lower()) for word in user_words]
    # Crear una bolsa de palabras para la entrada del usuario
    user_bag = [0] * len(words)
    for word in user_words:
        for i, w in enumerate(words):
            if w == word:
                user_bag[i] = 1

    # Hacer una predicción con el modelo
    prediction = model.predict(np.array([user_bag]))[0]
    predicted_label = labels[np.argmax(prediction)]

    # Seleccionar una respuesta aleatoria de las respuestas correspondientes a la etiqueta predicha
    response = random.choice([intent['responses'] for intent in data['intents'] if intent['tag'] == predicted_label][0])

    return response

#Definir el token del bot
TOKEN = 'Gtpturbo_bot:5934154756:AAEIs3z01STuTeulW86U296HKaH-ZT78nSw'

#Crear un objeto Updater para recibir actualizaciones del bot
updater = Updater(token=TOKEN, use_context=True)

#Obtener el dispatcher del updater para registrar los handlers de los comandos y mensajes
dispatcher = updater.dispatcher

#Registrar el handler para los mensajes de texto
dispatcher.add_handler(MessageHandler(Filters.text, telegram_chat))

#Iniciar el bot
updater.start_polling()

#Mantener el bot en ejecución hasta que se presione Ctrl-C
updater.idle()
#Función para procesar las entradas de usuario y generar respuestas
def process_input(user_input):
# Tokenizar y stemmizar la entrada del usuario
user_words = nltk.word_tokenize(user_input)
user_words = [stemmer.stem(word.lower()) for word in user_words]
# Crear una bolsa de palabras para la entrada del usuario
user_bag = [0] * len(words)
for word in user_words:
    for i, w in enumerate(words):
        if w == word:
            user_bag[i] = 1

# Hacer una predicción con el modelo
prediction = model.predict(np.array([user_bag]))[0]
predicted_label = labels[np.argmax(prediction)]

# Seleccionar una respuesta aleatoria de las respuestas correspondientes a la etiqueta predicha
response = random.choice([intent['responses'] for intent in data['intents'] if intent['tag'] == predicted_label][0])

return response

Función para interactuar con el usuario a través de Telegram
def telegram_chat(update, context):

# Obtener el mensaje de texto del usuario
user_input = update.message.text
# Procesar la entrada del usuario y obtener la respuesta del chatbot
response = process_input(user_input)

# Enviar la respuesta al usuario
update.message.reply_text(response)
# Out:
#   Cell In[2], line 231
#     user_words = nltk.word_tokenize(user_input)
#     ^
# IndentationError: expected an indented block after function definition on line 229

# %%
pip install nltk

# %%
import nltk
nltk.download('punkt')

# %%
import json
import random
import numpy as np
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Dropout
from tensorflow.keras.optimizers import SGD
from tensorflow.keras.models import load_model
import nltk
from nltk.stem import PorterStemmer

# Descargar los datos necesarios de NLTK
nltk.download('punkt')

# Crear el objeto stemmer
stemmer = PorterStemmer()

# Leer el archivo intents.json
with open('intents.json') as file:
    data = json.load(file)

# Inicializar las listas necesarias
words = []
labels = []
docs_x = []
docs_y = []

# Recorrer los patrones en el archivo JSON
for intent in data['intents']:
    for pattern in intent['patterns']:
        # Tokenizar las palabras
        wrds = nltk.word_tokenize(pattern)
        words.extend(wrds)
        # Agregar los patrones y las etiquetas correspondientes
        docs_x.append(wrds)
        docs_y.append(intent['tag'])

    # Agregar las etiquetas a la lista
    if intent['tag'] not in labels:
        labels.append(intent['tag'])

# Eliminar duplicados y ordenar la lista de palabras
words = sorted(list(set([stemmer.stem(w.lower()) for w in words])))

# Ordenar la lista de etiquetas
labels = sorted(labels)

# Crear una matriz de entrada para el modelo
training = []
output = []
out_empty = [0] * len(labels)

for idx, doc in enumerate(docs_x):
    # Crear una bolsa de palabras para cada patrón
    bag = []
    wrds = [stemmer.stem(w.lower()) for w in doc]

    for w in words:
        if w in wrds:
            bag.append(1)
        else:
            bag.append(0)

    # Crear una matriz de salida con la etiqueta correspondiente
    output_row = out_empty[:]
    output_row[labels.index(docs_y[idx])] = 1

    training.append(bag)
    output.append(output_row)

# Convertir las listas en arrays de Numpy
training = np.array(training)
output = np.array(output)

# Definir el modelo de la red neuronal
model = Sequential()
model.add(Dense(128, input_shape=(len(training[0]),), activation='relu'))
model.add(Dropout(0.5))
model.add(Dense(64, activation='relu'))
model.add(Dropout(0.5))
model.add(Dense(32, activation='relu'))
model.add(Dropout(0.5))
model.add(Dense(len(output[0]), activation='softmax'))

# Compilar y entrenar el modelo
model.compile(loss='categorical_crossentropy', optimizer=SGD(lr=0.01, momentum=0.9, nesterov=True), metrics=['accuracy'])
model.fit(training, output, epochs=200, batch_size=5, verbose=1)

# Guardar el modelo
model.save('chatbot_model.h5')

# Cargar el modelo
model = load_model('chatbot_model.h5')

#Función para procesar las entradas de usuario y generar respuestas
def process_input(user_input):
    # Tokenizar y stemmizar la entrada del usuario
    user_words = nltk.word_tokenize(user_input)
    user_words = [stemmer.stem(word.lower()) for word in user_words]
    # Crear una bolsa de palabras para la entrada del usuario
    user_bag = [0] * len(words)
    for word in user_words:
        for i, w in enumerate(words):
            if w == word:
                user_bag[i] = 1

    # Hacer una predicción con el modelo
    prediction = model.predict(np.array([user_bag]))[0]
    predicted_label = labels[np.argmax(prediction)]

    # Seleccionar una respuesta aleatoria de las respuestas correspondientes a la etiqueta predicha
    response = random.choice([intent['responses'] for intent in data['intents'] if intent['tag'] == predicted_label][0])

    return response
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\lenovo\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# WARNING:absl:`lr` is deprecated in Keras optimizer, please use `learning_rate` or use the legacy optimizer, e.g.,tf.keras.optimizers.legacy.SGD.
# Epoch 1/200
# 7/7 [==============================] - 1s 6ms/step - loss: 2.3189 - accuracy: 0.0286
# Epoch 2/200
# 7/7 [==============================] - 0s 4ms/step - loss: 2.1028 - accuracy: 0.2286
# Epoch 3/200
# 7/7 [==============================] - 0s 4ms/step - loss: 2.2059 - accuracy: 0.0857
# Epoch 4/200
# 7/7 [==============================] - 0s 3ms/step - loss: 2.1656 - accuracy: 0.2286
# Epoch 5/200
# 7/7 [==============================] - 0s 5ms/step - loss: 2.1642 - accuracy: 0.2286
# Epoch 6/200
# 7/7 [==============================] - 0s 5ms/step - loss: 2.1385 - accuracy: 0.0571
# Epoch 7/200
# 7/7 [==============================] - 0s 4ms/step - loss: 2.0956 - accuracy: 0.2286
# Epoch 8/200
# 7/7 [==============================] - 0s 5ms/step - loss: 2.1155 - accuracy: 0.1714
# Epoch 9/200
# 7/7 [==============================] - 0s 5ms/step - loss: 2.0156 - accuracy: 0.2286
# Epoch 10/200
# 7/7 [==============================] - 0s 4ms/step - loss: 2.1287 - accuracy: 0.1143
# Epoch 11/200
# 7/7 [==============================] - 0s 5ms/step - loss: 2.0236 - accuracy: 0.2286
# Epoch 12/200
# 7/7 [==============================] - 0s 4ms/step - loss: 1.9953 - accuracy: 0.2857
# Epoch 13/200
# 7/7 [==============================] - 0s 4ms/step - loss: 1.9564 - accuracy: 0.2286
# Epoch 14/200
# 7/7 [==============================] - 0s 4ms/step - loss: 1.9184 - accuracy: 0.3143
# Epoch 15/200
# 7/7 [==============================] - 0s 4ms/step - loss: 2.0126 - accuracy: 0.2286
# Epoch 16/200
# 7/7 [==============================] - 0s 4ms/step - loss: 1.8762 - accuracy: 0.2571
# Epoch 17/200
# 7/7 [==============================] - 0s 4ms/step - loss: 1.6847 - accuracy: 0.3714
# Epoch 18/200
# 7/7 [==============================] - 0s 4ms/step - loss: 1.9752 - accuracy: 0.2286
# Epoch 19/200
# 7/7 [==============================] - 0s 4ms/step - loss: 1.8743 - accuracy: 0.2571
# Epoch 20/200
# 7/7 [==============================] - 0s 6ms/step - loss: 1.7371 - accuracy: 0.4000
# Epoch 21/200
# 7/7 [==============================] - 0s 5ms/step - loss: 1.6256 - accuracy: 0.3714
# Epoch 22/200
# 7/7 [==============================] - 0s 4ms/step - loss: 1.5177 - accuracy: 0.4571
# Epoch 23/200
# 7/7 [==============================] - 0s 5ms/step - loss: 1.4787 - accuracy: 0.5143
# Epoch 24/200
# 7/7 [==============================] - 0s 5ms/step - loss: 1.6080 - accuracy: 0.2857
# Epoch 25/200
# 7/7 [==============================] - 0s 5ms/step - loss: 1.5486 - accuracy: 0.4571
# Epoch 26/200
# 7/7 [==============================] - 0s 4ms/step - loss: 1.4897 - accuracy: 0.4571
# Epoch 27/200
# 7/7 [==============================] - 0s 4ms/step - loss: 1.5537 - accuracy: 0.4571
# Epoch 28/200
# 7/7 [==============================] - 0s 5ms/step - loss: 1.5229 - accuracy: 0.5143
# Epoch 29/200
# 7/7 [==============================] - 0s 4ms/step - loss: 1.5720 - accuracy: 0.5143
# Epoch 30/200
# 7/7 [==============================] - 0s 4ms/step - loss: 1.2667 - accuracy: 0.5429
# Epoch 31/200
# 7/7 [==============================] - 0s 5ms/step - loss: 1.3588 - accuracy: 0.6857
# Epoch 32/200
# 7/7 [==============================] - 0s 4ms/step - loss: 1.4244 - accuracy: 0.5429
# Epoch 33/200
# 7/7 [==============================] - 0s 4ms/step - loss: 1.2602 - accuracy: 0.5429
# Epoch 34/200
# 7/7 [==============================] - 0s 5ms/step - loss: 1.1471 - accuracy: 0.6286
# Epoch 35/200
# 7/7 [==============================] - 0s 4ms/step - loss: 1.1940 - accuracy: 0.4857
# Epoch 36/200
# 7/7 [==============================] - 0s 4ms/step - loss: 1.2072 - accuracy: 0.6000
# Epoch 37/200
# 7/7 [==============================] - 0s 5ms/step - loss: 1.0626 - accuracy: 0.6286
# Epoch 38/200
# 7/7 [==============================] - 0s 4ms/step - loss: 1.0239 - accuracy: 0.6571
# Epoch 39/200
# 7/7 [==============================] - 0s 5ms/step - loss: 1.0815 - accuracy: 0.6286
# Epoch 40/200
# 7/7 [==============================] - 0s 4ms/step - loss: 1.1373 - accuracy: 0.7143
# Epoch 41/200
# 7/7 [==============================] - 0s 5ms/step - loss: 0.8971 - accuracy: 0.7714
# Epoch 42/200
# 7/7 [==============================] - 0s 4ms/step - loss: 1.1690 - accuracy: 0.6000
# Epoch 43/200
# 7/7 [==============================] - 0s 5ms/step - loss: 0.9174 - accuracy: 0.7714
# Epoch 44/200
# 7/7 [==============================] - 0s 7ms/step - loss: 1.1676 - accuracy: 0.6000
# Epoch 45/200
# 7/7 [==============================] - 0s 5ms/step - loss: 0.9608 - accuracy: 0.7143
# Epoch 46/200
# 7/7 [==============================] - 0s 4ms/step - loss: 0.8521 - accuracy: 0.7143
# Epoch 47/200
# 7/7 [==============================] - 0s 4ms/step - loss: 0.9968 - accuracy: 0.6857
# Epoch 48/200
# 7/7 [==============================] - 0s 6ms/step - loss: 0.9361 - accuracy: 0.7143
# Epoch 49/200
# 7/7 [==============================] - 0s 5ms/step - loss: 0.8758 - accuracy: 0.8000
# Epoch 50/200
# 7/7 [==============================] - 0s 5ms/step - loss: 0.9991 - accuracy: 0.6571
# Epoch 51/200
# 7/7 [==============================] - 0s 4ms/step - loss: 0.9673 - accuracy: 0.6571
# Epoch 52/200
# 7/7 [==============================] - 0s 4ms/step - loss: 0.7690 - accuracy: 0.7143
# Epoch 53/200
# 7/7 [==============================] - 0s 4ms/step - loss: 0.7421 - accuracy: 0.7429
# Epoch 54/200
# 7/7 [==============================] - 0s 5ms/step - loss: 0.8182 - accuracy: 0.7143
# Epoch 55/200
# 7/7 [==============================] - 0s 5ms/step - loss: 0.7752 - accuracy: 0.7714
# Epoch 56/200
# 7/7 [==============================] - 0s 6ms/step - loss: 0.9430 - accuracy: 0.7714
# Epoch 57/200
# 7/7 [==============================] - 0s 5ms/step - loss: 0.8637 - accuracy: 0.5714
# Epoch 58/200
# 7/7 [==============================] - 0s 5ms/step - loss: 0.4978 - accuracy: 0.8857
# Epoch 59/200
# 7/7 [==============================] - 0s 4ms/step - loss: 0.5103 - accuracy: 0.8857
# Epoch 60/200
# 7/7 [==============================] - 0s 5ms/step - loss: 0.7527 - accuracy: 0.8000
# Epoch 61/200
# 7/7 [==============================] - 0s 6ms/step - loss: 0.6768 - accuracy: 0.7714
# Epoch 62/200
# 7/7 [==============================] - 0s 4ms/step - loss: 0.4964 - accuracy: 0.8286
# Epoch 63/200
# 7/7 [==============================] - 0s 5ms/step - loss: 0.6150 - accuracy: 0.8286
# Epoch 64/200
# 7/7 [==============================] - 0s 4ms/step - loss: 0.9792 - accuracy: 0.7429
# Epoch 65/200
# 7/7 [==============================] - 0s 4ms/step - loss: 0.6121 - accuracy: 0.8000
# Epoch 66/200
# 7/7 [==============================] - 0s 4ms/step - loss: 0.6372 - accuracy: 0.7714
# Epoch 67/200
# 7/7 [==============================] - 0s 4ms/step - loss: 0.4812 - accuracy: 0.8286
# Epoch 68/200
# 7/7 [==============================] - 0s 4ms/step - loss: 0.5980 - accuracy: 0.8857
# Epoch 69/200
# 7/7 [==============================] - 0s 4ms/step - loss: 0.4147 - accuracy: 0.9143
# Epoch 70/200
# 7/7 [==============================] - 0s 4ms/step - loss: 0.4740 - accuracy: 0.9143
# Epoch 71/200
# 7/7 [==============================] - 0s 4ms/step - loss: 0.6760 - accuracy: 0.7429
# Epoch 72/200
# 7/7 [==============================] - 0s 4ms/step - loss: 0.5941 - accuracy: 0.8286
# Epoch 73/200
# 7/7 [==============================] - 0s 4ms/step - loss: 0.4228 - accuracy: 0.8857
# Epoch 74/200
# 7/7 [==============================] - 0s 6ms/step - loss: 0.4817 - accuracy: 0.8857
# Epoch 75/200
# 7/7 [==============================] - 0s 7ms/step - loss: 0.2845 - accuracy: 0.9143
# Epoch 76/200
# 7/7 [==============================] - 0s 5ms/step - loss: 0.3970 - accuracy: 0.8857
# Epoch 77/200
# 7/7 [==============================] - 0s 5ms/step - loss: 0.4382 - accuracy: 0.8571
# Epoch 78/200
# 7/7 [==============================] - 0s 2ms/step - loss: 0.6659 - accuracy: 0.8000
# Epoch 79/200
# 7/7 [==============================] - 0s 4ms/step - loss: 0.7247 - accuracy: 0.7714
# Epoch 80/200
# 7/7 [==============================] - 0s 6ms/step - loss: 0.7130 - accuracy: 0.8571
# Epoch 81/200
# 7/7 [==============================] - 0s 5ms/step - loss: 0.3871 - accuracy: 0.8857
# Epoch 82/200
# 7/7 [==============================] - 0s 7ms/step - loss: 0.6600 - accuracy: 0.8000
# Epoch 83/200
# 7/7 [==============================] - 0s 4ms/step - loss: 0.4207 - accuracy: 0.8286
# Epoch 84/200
# 7/7 [==============================] - 0s 5ms/step - loss: 0.4061 - accuracy: 0.8857
# Epoch 85/200
# 7/7 [==============================] - 0s 5ms/step - loss: 0.7320 - accuracy: 0.8571
# Epoch 86/200
# 7/7 [==============================] - 0s 6ms/step - loss: 0.2669 - accuracy: 0.8857
# Epoch 87/200
# 7/7 [==============================] - 0s 6ms/step - loss: 0.4528 - accuracy: 0.9143
# Epoch 88/200
# 7/7 [==============================] - 0s 4ms/step - loss: 0.4894 - accuracy: 0.8571
# Epoch 89/200
# 7/7 [==============================] - 0s 4ms/step - loss: 0.4215 - accuracy: 0.9143
# Epoch 90/200
# 7/7 [==============================] - 0s 3ms/step - loss: 0.2578 - accuracy: 0.9429
# Epoch 91/200
# 7/7 [==============================] - 0s 3ms/step - loss: 0.2492 - accuracy: 0.9143
# Epoch 92/200
# 7/7 [==============================] - 0s 4ms/step - loss: 0.4704 - accuracy: 0.8286
# Epoch 93/200
# 7/7 [==============================] - 0s 4ms/step - loss: 0.4827 - accuracy: 0.8571
# Epoch 94/200
# 7/7 [==============================] - 0s 3ms/step - loss: 0.2741 - accuracy: 0.8857
# Epoch 95/200
# 7/7 [==============================] - 0s 3ms/step - loss: 0.5189 - accuracy: 0.8000
# Epoch 96/200
# 7/7 [==============================] - 0s 3ms/step - loss: 0.3897 - accuracy: 0.8571
# Epoch 97/200
# 7/7 [==============================] - 0s 4ms/step - loss: 0.2682 - accuracy: 0.9429
# Epoch 98/200
# 7/7 [==============================] - 0s 3ms/step - loss: 0.3062 - accuracy: 0.8857
# Epoch 99/200
# 7/7 [==============================] - 0s 4ms/step - loss: 0.6114 - accuracy: 0.8286
# Epoch 100/200
# 7/7 [==============================] - 0s 4ms/step - loss: 0.5271 - accuracy: 0.8000
# Epoch 101/200
# 7/7 [==============================] - 0s 4ms/step - loss: 0.5032 - accuracy: 0.8286
# Epoch 102/200
# 7/7 [==============================] - 0s 3ms/step - loss: 0.3042 - accuracy: 0.9143
# Epoch 103/200
# 7/7 [==============================] - 0s 3ms/step - loss: 0.2688 - accuracy: 0.9143
# Epoch 104/200
# 7/7 [==============================] - 0s 3ms/step - loss: 0.2574 - accuracy: 0.9143
# Epoch 105/200
# 7/7 [==============================] - 0s 4ms/step - loss: 0.2292 - accuracy: 0.9429
# Epoch 106/200
# 7/7 [==============================] - 0s 4ms/step - loss: 0.3850 - accuracy: 0.9143
# Epoch 107/200
# 7/7 [==============================] - 0s 5ms/step - loss: 0.2344 - accuracy: 0.9429
# Epoch 108/200
# 7/7 [==============================] - 0s 5ms/step - loss: 0.4171 - accuracy: 0.8857
# Epoch 109/200
# 7/7 [==============================] - 0s 7ms/step - loss: 0.2948 - accuracy: 0.9429
# Epoch 110/200
# 7/7 [==============================] - 0s 6ms/step - loss: 0.2901 - accuracy: 0.9143
# Epoch 111/200
# 7/7 [==============================] - 0s 7ms/step - loss: 0.2803 - accuracy: 0.9714
# Epoch 112/200
# 7/7 [==============================] - 0s 5ms/step - loss: 0.3217 - accuracy: 0.8857
# Epoch 113/200
# 7/7 [==============================] - 0s 8ms/step - loss: 0.3249 - accuracy: 0.8571
# Epoch 114/200
# 7/7 [==============================] - 0s 5ms/step - loss: 0.1606 - accuracy: 0.9429
# Epoch 115/200
# 7/7 [==============================] - 0s 5ms/step - loss: 0.3114 - accuracy: 0.9143
# Epoch 116/200
# 7/7 [==============================] - 0s 6ms/step - loss: 0.3207 - accuracy: 0.9143
# Epoch 117/200
# 7/7 [==============================] - 0s 4ms/step - loss: 0.3729 - accuracy: 0.8571
# Epoch 118/200
# 7/7 [==============================] - 0s 5ms/step - loss: 0.1431 - accuracy: 1.0000
# Epoch 119/200
# 7/7 [==============================] - 0s 5ms/step - loss: 0.1605 - accuracy: 0.9429
# Epoch 120/200
# 7/7 [==============================] - 0s 4ms/step - loss: 0.6253 - accuracy: 0.8571
# Epoch 121/200
# 7/7 [==============================] - 0s 4ms/step - loss: 0.3787 - accuracy: 0.8857
# Epoch 122/200
# 7/7 [==============================] - 0s 4ms/step - loss: 0.2280 - accuracy: 0.9143
# Epoch 123/200
# 7/7 [==============================] - 0s 6ms/step - loss: 0.2522 - accuracy: 0.9714
# Epoch 124/200
# 7/7 [==============================] - 0s 5ms/step - loss: 0.4412 - accuracy: 0.8286
# Epoch 125/200
# 7/7 [==============================] - 0s 5ms/step - loss: 0.2515 - accuracy: 0.9429
# Epoch 126/200
# 7/7 [==============================] - 0s 5ms/step - loss: 0.3826 - accuracy: 0.8571
# Epoch 127/200
# 7/7 [==============================] - 0s 4ms/step - loss: 0.5659 - accuracy: 0.8571
# Epoch 128/200
# 7/7 [==============================] - 0s 5ms/step - loss: 0.4801 - accuracy: 0.9143
# Epoch 129/200
# 7/7 [==============================] - 0s 5ms/step - loss: 0.1383 - accuracy: 0.9714
# Epoch 130/200
# 7/7 [==============================] - 0s 4ms/step - loss: 0.1901 - accuracy: 0.9429
# Epoch 131/200
# 7/7 [==============================] - 0s 5ms/step - loss: 0.3495 - accuracy: 0.9143
# Epoch 132/200
# 7/7 [==============================] - 0s 7ms/step - loss: 0.3973 - accuracy: 0.8000
# Epoch 133/200
# 7/7 [==============================] - 0s 5ms/step - loss: 0.2311 - accuracy: 0.9143
# Epoch 134/200
# 7/7 [==============================] - 0s 6ms/step - loss: 0.2922 - accuracy: 0.9714
# Epoch 135/200
# 7/7 [==============================] - 0s 5ms/step - loss: 0.2549 - accuracy: 0.9714
# Epoch 136/200
# 7/7 [==============================] - 0s 5ms/step - loss: 0.0729 - accuracy: 1.0000
# Epoch 137/200
# 7/7 [==============================] - 0s 6ms/step - loss: 0.1644 - accuracy: 0.9143
# Epoch 138/200
# 7/7 [==============================] - 0s 5ms/step - loss: 0.1513 - accuracy: 0.9714
# Epoch 139/200
# 7/7 [==============================] - 0s 5ms/step - loss: 0.1695 - accuracy: 0.9429
# Epoch 140/200
# 7/7 [==============================] - 0s 6ms/step - loss: 0.2763 - accuracy: 0.8857
# Epoch 141/200
# 7/7 [==============================] - 0s 4ms/step - loss: 0.2799 - accuracy: 0.8857
# Epoch 142/200
# 7/7 [==============================] - 0s 5ms/step - loss: 0.0707 - accuracy: 0.9714
# Epoch 143/200
# 7/7 [==============================] - 0s 3ms/step - loss: 0.3384 - accuracy: 0.8571
# Epoch 144/200
# 7/7 [==============================] - 0s 5ms/step - loss: 0.3607 - accuracy: 0.8857
# Epoch 145/200
# 7/7 [==============================] - 0s 5ms/step - loss: 0.2534 - accuracy: 0.9429
# Epoch 146/200
# 7/7 [==============================] - 0s 5ms/step - loss: 0.1491 - accuracy: 0.9429
# Epoch 147/200
# 7/7 [==============================] - 0s 5ms/step - loss: 0.1937 - accuracy: 0.9143
# Epoch 148/200
# 7/7 [==============================] - 0s 5ms/step - loss: 0.4090 - accuracy: 0.8571
# Epoch 149/200
# 7/7 [==============================] - 0s 5ms/step - loss: 0.2404 - accuracy: 0.9429
# Epoch 150/200
# 7/7 [==============================] - 0s 5ms/step - loss: 0.1480 - accuracy: 0.9429
# Epoch 151/200
# 7/7 [==============================] - 0s 7ms/step - loss: 0.2282 - accuracy: 0.9429
# Epoch 152/200
# 7/7 [==============================] - 0s 4ms/step - loss: 0.3501 - accuracy: 0.8571
# Epoch 153/200
# 7/7 [==============================] - 0s 4ms/step - loss: 0.1516 - accuracy: 0.9714
# Epoch 154/200
# 7/7 [==============================] - 0s 11ms/step - loss: 0.2405 - accuracy: 0.9429
# Epoch 155/200
# 7/7 [==============================] - 0s 4ms/step - loss: 0.1673 - accuracy: 0.9714
# Epoch 156/200
# 7/7 [==============================] - 0s 5ms/step - loss: 0.2504 - accuracy: 0.9429
# Epoch 157/200
# 7/7 [==============================] - 0s 4ms/step - loss: 0.1275 - accuracy: 1.0000
# Epoch 158/200
# 7/7 [==============================] - 0s 5ms/step - loss: 0.3450 - accuracy: 0.9143
# Epoch 159/200
# 7/7 [==============================] - 0s 6ms/step - loss: 0.3123 - accuracy: 0.8857
# Epoch 160/200
# 7/7 [==============================] - 0s 3ms/step - loss: 0.4028 - accuracy: 0.8857
# Epoch 161/200
# 7/7 [==============================] - 0s 5ms/step - loss: 0.4499 - accuracy: 0.9143
# Epoch 162/200
# 7/7 [==============================] - 0s 5ms/step - loss: 0.5743 - accuracy: 0.8286
# Epoch 163/200
# 7/7 [==============================] - 0s 5ms/step - loss: 0.2489 - accuracy: 0.8857
# Epoch 164/200
# 7/7 [==============================] - 0s 3ms/step - loss: 0.3589 - accuracy: 0.9429
# Epoch 165/200
# 7/7 [==============================] - 0s 4ms/step - loss: 0.2208 - accuracy: 0.9429
# Epoch 166/200
# 7/7 [==============================] - 0s 5ms/step - loss: 0.6596 - accuracy: 0.8286
# Epoch 167/200
# 7/7 [==============================] - 0s 5ms/step - loss: 0.2066 - accuracy: 0.9429
# Epoch 168/200
# 7/7 [==============================] - 0s 6ms/step - loss: 0.2125 - accuracy: 0.9143
# Epoch 169/200
# 7/7 [==============================] - 0s 4ms/step - loss: 0.2654 - accuracy: 0.9143
# Epoch 170/200
# 7/7 [==============================] - 0s 5ms/step - loss: 0.2925 - accuracy: 0.9429
# Epoch 171/200
# 7/7 [==============================] - 0s 6ms/step - loss: 0.2187 - accuracy: 0.9429
# Epoch 172/200
# 7/7 [==============================] - 0s 3ms/step - loss: 0.2266 - accuracy: 0.9429
# Epoch 173/200
# 7/7 [==============================] - 0s 6ms/step - loss: 0.7234 - accuracy: 0.8571
# Epoch 174/200
# 7/7 [==============================] - 0s 6ms/step - loss: 0.1947 - accuracy: 0.9429
# Epoch 175/200
# 7/7 [==============================] - 0s 6ms/step - loss: 0.1814 - accuracy: 0.9714
# Epoch 176/200
# 7/7 [==============================] - 0s 6ms/step - loss: 0.2338 - accuracy: 0.9143
# Epoch 177/200
# 7/7 [==============================] - 0s 6ms/step - loss: 0.3790 - accuracy: 0.8571
# Epoch 178/200
# 7/7 [==============================] - 0s 3ms/step - loss: 0.1832 - accuracy: 0.9714
# Epoch 179/200
# 7/7 [==============================] - 0s 5ms/step - loss: 0.0479 - accuracy: 1.0000
# Epoch 180/200
# 7/7 [==============================] - 0s 6ms/step - loss: 0.3405 - accuracy: 0.8857
# Epoch 181/200
# 7/7 [==============================] - 0s 5ms/step - loss: 0.3831 - accuracy: 0.8571
# Epoch 182/200
# 7/7 [==============================] - 0s 6ms/step - loss: 0.1364 - accuracy: 0.9429
# Epoch 183/200
# 7/7 [==============================] - 0s 6ms/step - loss: 0.2751 - accuracy: 0.9143
# Epoch 184/200
# 7/7 [==============================] - 0s 6ms/step - loss: 0.1001 - accuracy: 0.9714
# Epoch 185/200
# 7/7 [==============================] - 0s 6ms/step - loss: 0.3525 - accuracy: 0.8571
# Epoch 186/200
# 7/7 [==============================] - 0s 3ms/step - loss: 0.6160 - accuracy: 0.9429
# Epoch 187/200
# 7/7 [==============================] - 0s 6ms/step - loss: 0.2411 - accuracy: 0.9143
# Epoch 188/200
# 7/7 [==============================] - 0s 3ms/step - loss: 0.2669 - accuracy: 0.9143
# Epoch 189/200
# 7/7 [==============================] - 0s 6ms/step - loss: 0.2955 - accuracy: 0.8857
# Epoch 190/200
# 7/7 [==============================] - 0s 3ms/step - loss: 0.1803 - accuracy: 0.9429
# Epoch 191/200
# 7/7 [==============================] - 0s 6ms/step - loss: 0.1525 - accuracy: 0.9429
# Epoch 192/200
# 7/7 [==============================] - 0s 3ms/step - loss: 0.0793 - accuracy: 1.0000
# Epoch 193/200
# 7/7 [==============================] - 0s 5ms/step - loss: 0.2430 - accuracy: 0.9429
# Epoch 194/200
# 7/7 [==============================] - 0s 3ms/step - loss: 0.1571 - accuracy: 0.9429
# Epoch 195/200
# 7/7 [==============================] - 0s 5ms/step - loss: 0.1727 - accuracy: 0.9143
# Epoch 196/200
# 7/7 [==============================] - 0s 6ms/step - loss: 0.1671 - accuracy: 0.9429
# Epoch 197/200
# 7/7 [==============================] - 0s 6ms/step - loss: 0.1354 - accuracy: 0.9429
# Epoch 198/200
# 7/7 [==============================] - 0s 4ms/step - loss: 0.0966 - accuracy: 1.0000
# Epoch 199/200
# 7/7 [==============================] - 0s 4ms/step - loss: 0.1908 - accuracy: 0.9429
# Epoch 200/200
# 7/7 [==============================] - 0s 7ms/step - loss: 0.1437 - accuracy: 0.9429
